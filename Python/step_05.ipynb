# %%
class Product:
    def __init__(self,name, price, quantity):
        print(f"An instance with name: {name} has been derived from Product class.")
        
        self.__name = name
        self.price = price
        self.quantity = quantity
    
    @property
    def name(self):
        return self.__name
    
    @name.setter
    def name(self, value):
        self.__name = value

# %%
item1 = Product("Laptop",799.99,2)
item1.name = "HP Laptop"
print(item1.name)
print(item1.price)

print(item1.quantity)
# Out:
# An instance with name: Laptop has been derived from Product class.
# HP Laptop
# 799.99
# 2

# %%
item2 = Product()

# dinamik özellik tanımı 
item2.__name = "Computer"
item2.__price = 1999.99
item2.quantity = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 item2 = Product()
#       3 # dinamik özellik tanımı
#       4 item2.__name = "Computer"
#
# TypeError: __init__() missing 3 required positional arguments: 'name', 'price', and 'quantity'
